# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Angel González\OneDrive\Documentos\Angel Tareas LIT\Concentración de Analítica de Datos\Dashboard_Final\Final\df.csv").drop(columns = "Unnamed: 0", axis = 1)
df
# Out:
#            Veloc     Acele     Des_x     Des_y     Des_z     Presn     VelPr  \
# 0       0.191246  0.069119  0.117477  0.256040  0.009921  1.000000  0.000000
# 1       0.227600  0.022417  0.170484  0.269475  0.056222  1.000000  0.000000
# 2       0.197158  0.016593  0.090188  0.256400  0.071611  0.833333  0.250000
# 3       0.142945  0.052955  0.073806  0.157591  0.050316  0.833333  0.500000
# 4       0.139948  0.049105  0.122286  0.138448  0.042417  0.666667  0.500000
# ...          ...       ...       ...       ...       ...       ...       ...
# 139585  0.066346  0.056541  0.126420  0.073793  0.003030  0.549242  0.055556
# 139586  0.077132  0.055018  0.150901  0.077506  0.001316  0.553030  0.055556
# 139587  0.073022  0.054559  0.142266  0.074820  0.001544  0.556818  0.055556
# 139588  0.061562  0.052535  0.115257  0.071348  0.002059  0.560606  0.039683
# 139589  0.059580  0.047421  0.112786  0.068472  0.002529  0.553030  0.047619
#
# ...

# %%
df.head(3).to_dict()
# Out:
# {'Veloc': {0: 0.19124645, 1: 0.22760026, 2: 0.19715849},
#  'Acele': {0: 0.0691194, 1: 0.02241679, 2: 0.01659272},
#  'Des_x': {0: 0.11747728, 1: 0.17048357, 2: 0.09018762},
#  'Des_y': {0: 0.25603954, 1: 0.26947474, 2: 0.25640043},
#  'Des_z': {0: 0.00992126, 1: 0.05622194, 2: 0.07161065},
#  'Presn': {0: 1.0, 1: 1.0, 2: 0.83333333},
#  'VelPr': {0: 0.0, 1: 0.0, 2: 0.25},
#  'AcePr': {0: 0.0, 1: 0.0, 2: 0.5},
#  'F5EEX': {0: 0.35484574, 1: 0.38291905, 2: 0.28546975},
#  'F6EES': {0: 0.44525718, 1: 0.44084049, 2: 0.42313408},
#  'F8EIX': {0: 0.38424866, 1: 0.38902167, 2: 0.38670503},
#  'F7EIS': {0: 0.31271884, 1: 0.32343451, 2: 0.32980433},
#  'F9EEX': {0: 0.29204625, 1: 0.32801898, 2: 0.27260433},
#  'F10ES': {0: 0.39168162, 1: 0.40295526, 2: 0.40339618},
#  'F11EX': {0: 0.27387587, 1: 0.29222469, 2: 0.28758665},
#  'F12ES': {0: 0.31232964, 1: 0.30689596, 2: 0.30179967},
#  'F13EV': {0: 0.67624349, 1: 0.67222998, 2: 0.66936498},
# ...
